# %% [raw]
# Tasks
# 1. Load the Data

# %%
import pandas as pd
df_sales_data = pd.read_csv('sales_data.csv')
df_sales_data
# Out:
#      order_id customer_id product_id quantity  unit_price order_date  \
# 0     O966977      C00397      P0022        3       39.25   06-07-25
# 1     O696648      C00236      P0023        5       18.92   06-07-25
# 2     O202644      C00492      P0011        1       29.68   06-07-25
# 3     O501803      C00031      P0003        1       32.76   06-07-25
# 4     O322242      C00495      P0016        1       47.62   06-07-25
# ...       ...         ...        ...      ...         ...        ...
# 2995  O868860      C00233      P0001        5       43.40   06-07-25
# 2996  O949709      C00246      P0029        4       34.04   06-07-25
# 2997  O763639      C00182      P0026        1       42.34   06-07-25
# 2998  O753958      C00074      P0003        5       35.96   06-07-25
# 2999  O929624      C00405      P0004        3       43.23   06-07-25
#
#      delivery_status payment_method   region  discount_applied
# 0          Delivered         PayPal  Central              0.00
# ...

# %%
df_product_info = pd.read_csv('product_info.csv')
df_product_info
# Out:
#    product_id              product_name       category launch_date  \
# 0       P0001        Storage Product 39        Storage    11-03-25
# 1       P0002       Cleaning Product 82       Cleaning    18-08-24
# 2       P0003       Cleaning Product 85       Cleaning    15-07-24
# 3       P0004        Kitchen Product 82        Kitchen    19-04-25
# 4       P0005   Personal Care Product 1  Personal Care    20-10-24
# 5       P0006       Cleaning Product 16       Cleaning    09-10-24
# 6       P0007  Personal Care Product 64  Personal Care    30-09-24
# 7       P0008        Storage Product 47        Storage    29-08-24
# 8       P0009       Outdoors Product 13       Outdoors    18-04-25
# 9       P0010       Cleaning Product 70       Cleaning    14-08-24
# 10      P0011        Kitchen Product 53        Kitchen    25-03-25
# 11      P0012       Cleaning Product 29       Cleaning    19-04-25
# 12      P0013       Cleaning Product 94       Cleaning    17-06-25
# ...

# %%
df_customer_info = pd.read_csv('customer_info.csv')
df_customer_info
# Out:
#     customer_id                      email signup_date  gender   region  \
# 0        C00001     shaneramirez@gmail.com    26-04-25    Male  Central
# 1        C00002      jpeterson@bernard.com    11-08-24  Female  Central
# 2        C00003    howardmaurice@yahoo.com    15-05-25    male  Central
# 3        C00004        yherrera@arnold.org    14-06-25  FEMALE  Central
# 4        C00005    janetwilliams@gmail.com    02-05-25    Male     West
# ..          ...                        ...         ...     ...      ...
# 495      C00496         simsjohn@wiley.net    19-02-25   femle  Central
# 496      C00497  cameronwilliams@yahoo.com    30-12-24     NaN     West
# 497      C00498          ibarron@yahoo.com    21-06-25    male    South
# 498      C00499          karen26@gmail.com    02-10-24  Female    North
# 499      C00500   jasonjohnson@jackson.com    28-11-24    Male    North
#
#     loyalty_tier
# 0         Silver
# 1          gold
# 2          gold
# 3           GOLD
# ...

# %% [raw]
# 2.  Clean the Data

# %% [raw]
# - Standardising text formatting using .str.strip(), .str.lower(), .str.title()

# %%
df_sales_data = df_sales_data.apply(lambda x: x.astype(str).str.strip().str.lower().str.title() if x.dtype == "object" else x)
df_sales_data
# Out:
#      order_id customer_id product_id quantity  unit_price order_date  \
# 0     O966977      C00397      P0022        3       39.25   06-07-25
# 1     O696648      C00236      P0023        5       18.92   06-07-25
# 2     O202644      C00492      P0011        1       29.68   06-07-25
# 3     O501803      C00031      P0003        1       32.76   06-07-25
# 4     O322242      C00495      P0016        1       47.62   06-07-25
# ...       ...         ...        ...      ...         ...        ...
# 2995  O868860      C00233      P0001        5       43.40   06-07-25
# 2996  O949709      C00246      P0029        4       34.04   06-07-25
# 2997  O763639      C00182      P0026        1       42.34   06-07-25
# 2998  O753958      C00074      P0003        5       35.96   06-07-25
# 2999  O929624      C00405      P0004        3       43.23   06-07-25
#
#      delivery_status payment_method   region  discount_applied
# 0          Delivered         Paypal  Central              0.00
# ...

# %%
df_product_info=df_product_info.apply(lambda x: x.str.strip().str.lower().str.title() if x.dtype == "object" else x)
df_product_info
# Out:
#    product_id              product_name       category launch_date  \
# 0       P0001        Storage Product 39        Storage    11-03-25
# 1       P0002       Cleaning Product 82       Cleaning    18-08-24
# 2       P0003       Cleaning Product 85       Cleaning    15-07-24
# 3       P0004        Kitchen Product 82        Kitchen    19-04-25
# 4       P0005   Personal Care Product 1  Personal Care    20-10-24
# 5       P0006       Cleaning Product 16       Cleaning    09-10-24
# 6       P0007  Personal Care Product 64  Personal Care    30-09-24
# 7       P0008        Storage Product 47        Storage    29-08-24
# 8       P0009       Outdoors Product 13       Outdoors    18-04-25
# 9       P0010       Cleaning Product 70       Cleaning    14-08-24
# 10      P0011        Kitchen Product 53        Kitchen    25-03-25
# 11      P0012       Cleaning Product 29       Cleaning    19-04-25
# 12      P0013       Cleaning Product 94       Cleaning    17-06-25
# ...

# %%
df_customer_info=df_customer_info.apply(lambda x: x.str.strip().str.lower().str.title() if x.dtype == "object" else x)
df_customer_info
# Out:
#     customer_id                      email signup_date  gender   region  \
# 0        C00001     Shaneramirez@Gmail.Com    26-04-25    Male  Central
# 1        C00002      Jpeterson@Bernard.Com    11-08-24  Female  Central
# 2        C00003    Howardmaurice@Yahoo.Com    15-05-25    Male  Central
# 3        C00004        Yherrera@Arnold.Org    14-06-25  Female  Central
# 4        C00005    Janetwilliams@Gmail.Com    02-05-25    Male     West
# ..          ...                        ...         ...     ...      ...
# 495      C00496         Simsjohn@Wiley.Net    19-02-25   Femle  Central
# 496      C00497  Cameronwilliams@Yahoo.Com    30-12-24     NaN     West
# 497      C00498          Ibarron@Yahoo.Com    21-06-25    Male    South
# 498      C00499          Karen26@Gmail.Com    02-10-24  Female    North
# 499      C00500   Jasonjohnson@Jackson.Com    28-11-24    Male    North
#
#     loyalty_tier
# 0         Silver
# 1           Gold
# 2           Gold
# 3           Gold
# ...

# %% [raw]
# - Converting date columns (order_date, signup_date, launch_date) to datetime using
# pd.to_datetime()

# %%
df_sales_data['order_date'] = pd.to_datetime(df_sales_data['order_date'], format='%y-%m-%d', errors='coerce')
df_sales_data
# Out:
#      order_id customer_id product_id quantity  unit_price order_date  \
# 0     O966977      C00397      P0022        3       39.25 2006-07-25
# 1     O696648      C00236      P0023        5       18.92 2006-07-25
# 2     O202644      C00492      P0011        1       29.68 2006-07-25
# 3     O501803      C00031      P0003        1       32.76 2006-07-25
# 4     O322242      C00495      P0016        1       47.62 2006-07-25
# ...       ...         ...        ...      ...         ...        ...
# 2995  O868860      C00233      P0001        5       43.40 2006-07-25
# 2996  O949709      C00246      P0029        4       34.04 2006-07-25
# 2997  O763639      C00182      P0026        1       42.34 2006-07-25
# 2998  O753958      C00074      P0003        5       35.96 2006-07-25
# 2999  O929624      C00405      P0004        3       43.23 2006-07-25
#
#      delivery_status payment_method   region  discount_applied
# 0          Delivered         Paypal  Central              0.00
# ...

# %%
df_product_info['launch_date']=pd.to_datetime(df_product_info['launch_date'],format='%y-%m-%d', errors='coerce')
df_product_info
# Out:
#    product_id              product_name       category launch_date  \
# 0       P0001        Storage Product 39        Storage  2011-03-25
# 1       P0002       Cleaning Product 82       Cleaning  2018-08-24
# 2       P0003       Cleaning Product 85       Cleaning  2015-07-24
# 3       P0004        Kitchen Product 82        Kitchen  2019-04-25
# 4       P0005   Personal Care Product 1  Personal Care  2020-10-24
# 5       P0006       Cleaning Product 16       Cleaning  2009-10-24
# 6       P0007  Personal Care Product 64  Personal Care  2030-09-24
# 7       P0008        Storage Product 47        Storage  2029-08-24
# 8       P0009       Outdoors Product 13       Outdoors  2018-04-25
# 9       P0010       Cleaning Product 70       Cleaning  2014-08-24
# 10      P0011        Kitchen Product 53        Kitchen  2025-03-25
# 11      P0012       Cleaning Product 29       Cleaning  2019-04-25
# 12      P0013       Cleaning Product 94       Cleaning  2017-06-25
# ...

# %%
df_customer_info['signup_date']=pd.to_datetime(df_customer_info['signup_date'],format='%y-%m-%d', errors='coerce')
df_customer_info
# Out:
#     customer_id                      email signup_date  gender   region  \
# 0        C00001     Shaneramirez@Gmail.Com  2026-04-25    Male  Central
# 1        C00002      Jpeterson@Bernard.Com  2011-08-24  Female  Central
# 2        C00003    Howardmaurice@Yahoo.Com  2015-05-25    Male  Central
# 3        C00004        Yherrera@Arnold.Org  2014-06-25  Female  Central
# 4        C00005    Janetwilliams@Gmail.Com  2002-05-25    Male     West
# ..          ...                        ...         ...     ...      ...
# 495      C00496         Simsjohn@Wiley.Net  2019-02-25   Femle  Central
# 496      C00497  Cameronwilliams@Yahoo.Com  2030-12-24     NaN     West
# 497      C00498          Ibarron@Yahoo.Com  2021-06-25    Male    South
# 498      C00499          Karen26@Gmail.Com  2002-10-24  Female    North
# 499      C00500   Jasonjohnson@Jackson.Com  2028-11-24    Male    North
#
#     loyalty_tier
# 0         Silver
# 1           Gold
# 2           Gold
# 3           Gold
# ...

# %% [raw]
# - Handle missing values:

# %% [raw]
# -> Use .isnull().sum() to identify missing values

# %%
df_sales_data.isnull().sum()
# Out:
# order_id              0
# customer_id           0
# product_id            0
# quantity              0
# unit_price            1
# order_date            3
# delivery_status       0
# payment_method        0
# region                0
# discount_applied    517
# dtype: int64

# %%
df_product_info.isnull().sum()
# Out:
# product_id       0
# product_name     0
# category         0
# launch_date      0
# base_price       0
# supplier_code    0
# dtype: int64

# %%
df_customer_info.isnull().sum()
# Out:
# customer_id     3
# email           6
# signup_date     4
# gender          4
# region          3
# loyalty_tier    2
# dtype: int64

# %% [raw]
# -> Fill where appropriate

# %%
df_sales_data['order_id'] = df_sales_data['order_id'].fillna(0.0)
df_sales_data['customer_id'] = df_sales_data['customer_id'].fillna('unknown')
df_sales_data['product_id'] = df_sales_data['product_id'].fillna('unknown')
df_sales_data['quantity'] = df_sales_data['quantity'].fillna(0)
df_sales_data['unit_price'] = df_sales_data['unit_price'].fillna(00.00)
df_sales_data['order_date'] = df_sales_data['order_date'].fillna(df_sales_data['order_date'].mode()[0])
df_sales_data['delivery_status'] = df_sales_data['delivery_status'].fillna('unknown')
df_sales_data['payment_method'] = df_sales_data['payment_method'].fillna('unknown')

# %%
df_sales_data.isnull().sum() #no empty values anymore
# Out:
# order_id              0
# customer_id           0
# product_id            0
# quantity              0
# unit_price            0
# order_date            0
# delivery_status       0
# payment_method        0
# region                0
# discount_applied    517
# dtype: int64

# %%
df_customer_info['customer_id'] = df_customer_info['customer_id'].fillna('unknown')
df_customer_info['email'] = df_customer_info['email'].fillna('unknown')
df_customer_info['signup_date'] = df_customer_info['signup_date'].fillna(df_customer_info['signup_date'].mode()[0])
df_customer_info['gender'] = df_customer_info['gender'].fillna('unknown')
df_customer_info['region'] = df_customer_info['region'].fillna('unknown')
df_customer_info['loyalty_tier'] = df_customer_info['loyalty_tier'].fillna('unknown')

# %%
df_customer_info.isnull().sum()
# Out:
# customer_id     0
# email           0
# signup_date     0
# gender          0
# region          0
# loyalty_tier    0
# dtype: int64

# %% [raw]
# -> Drop only if necessary (explain your decision in markdown)

# %%
#only df_sales_data and df_customer_info tables need to drop the rows where 0.0 or unknown is 
#contained in columns: order_id  customer_id  product_id  
df_sales_data = df_sales_data[
    (df_sales_data['order_id'] != 0.0) &
    (df_sales_data['customer_id'] != 'unknown') &
    (df_sales_data['product_id'] != 'unknown')]
df_customer_info = df_customer_info[
    (df_customer_info['customer_id'] != 'unknown') &
    (df_customer_info['customer_id'] != 0.0)]

# %% [raw]
# - Remove duplicates:

# %% [raw]
# -> Use .duplicated() and .drop_duplicates() (e.g., by order_id)

# %%
#table1
#check the duplicates before drop
df_sales_data[df_sales_data.duplicated(subset='order_id', keep=False)]
# Out:
#      order_id customer_id product_id quantity  unit_price order_date  \
# 156   O515400      C00103      P0024        4       44.15 2006-07-25
# 793   O916245      C00390      P0010        1       24.57 2006-07-25
# 1461  O515400      C00389      P0027        2       22.04 2006-07-25
# 2712  O916245      C00070      P0011        3       20.83 2006-07-25
#
#      delivery_status payment_method region  discount_applied
# 156        Delivered         Paypal   East              0.15
# 793          Delayed         Paypal  South              0.10
# 1461         Delayed         Paypal  North              0.05
# 2712         Delayed  Bank Transfer   West              0.05

# %%
#table1
df_sales_data = df_sales_data[~df_sales_data.duplicated(subset='order_id', keep=False)]
#removing all duplicates because I am not sure which one is the most logical to keep
df_sales_data
# Out:
#      order_id customer_id product_id quantity  unit_price order_date  \
# 0     O966977      C00397      P0022        3       39.25 2006-07-25
# 1     O696648      C00236      P0023        5       18.92 2006-07-25
# 2     O202644      C00492      P0011        1       29.68 2006-07-25
# 3     O501803      C00031      P0003        1       32.76 2006-07-25
# 4     O322242      C00495      P0016        1       47.62 2006-07-25
# ...       ...         ...        ...      ...         ...        ...
# 2995  O868860      C00233      P0001        5       43.40 2006-07-25
# 2996  O949709      C00246      P0029        4       34.04 2006-07-25
# 2997  O763639      C00182      P0026        1       42.34 2006-07-25
# 2998  O753958      C00074      P0003        5       35.96 2006-07-25
# 2999  O929624      C00405      P0004        3       43.23 2006-07-25
#
#      delivery_status payment_method   region  discount_applied
# 0          Delivered         Paypal  Central              0.00
# ...

# %%
#table1
df_sales_data[df_sales_data.duplicated(subset='order_id', keep=False)]
#checking if they were successfully removed - yes
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, product_id, quantity, unit_price, order_date, delivery_status, payment_method, region, discount_applied]
# Index: []

# %%
#table2
df_product_info[df_product_info.duplicated(subset='product_id', keep=False)]
#therea are no duplicates in the table originally
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, launch_date, base_price, supplier_code]
# Index: []

# %%
#table3
#check the duplicates before drop
df_customer_info[df_customer_info.duplicated(subset='customer_id', keep=False)]
# Out:
# Empty DataFrame
# Columns: [customer_id, email, signup_date, gender, region, loyalty_tier]
# Index: []

# %%
#table3
df_customer_info = df_customer_info[~df_customer_info.duplicated(subset='customer_id', keep=False)]
df_customer_info
# Out:
#     customer_id                      email signup_date   gender   region  \
# 0        C00001     Shaneramirez@Gmail.Com  2026-04-25     Male  Central
# 1        C00002      Jpeterson@Bernard.Com  2011-08-24   Female  Central
# 2        C00003    Howardmaurice@Yahoo.Com  2015-05-25     Male  Central
# 3        C00004        Yherrera@Arnold.Org  2014-06-25   Female  Central
# 4        C00005    Janetwilliams@Gmail.Com  2002-05-25     Male     West
# ..          ...                        ...         ...      ...      ...
# 495      C00496         Simsjohn@Wiley.Net  2019-02-25    Femle  Central
# 496      C00497  Cameronwilliams@Yahoo.Com  2030-12-24  unknown     West
# 497      C00498          Ibarron@Yahoo.Com  2021-06-25     Male    South
# 498      C00499          Karen26@Gmail.Com  2002-10-24   Female    North
# 499      C00500   Jasonjohnson@Jackson.Com  2028-11-24     Male    North
#
#     loyalty_tier
# 0         Silver
# 1           Gold
# 2           Gold
# 3           Gold
# ...

# %%
#table3
df_customer_info[df_customer_info.duplicated(subset='customer_id', keep=False)]
#checking if they were successfully removed - yes
# Out:
# Empty DataFrame
# Columns: [customer_id, email, signup_date, gender, region, loyalty_tier]
# Index: []

# %% [raw]
# - Validate numeric columns:

# %% [raw]
# ->  Ensure quantity, unit_price, and discount_applied are all non-negative

# %%
#converting to numeric all the values in these 3 columns
df_sales_data.loc[:, 'quantity'] = pd.to_numeric(df_sales_data['quantity'], errors='coerce')
df_sales_data.loc[:, 'unit_price'] = pd.to_numeric(df_sales_data['unit_price'], errors='coerce')
df_sales_data.loc[:, 'discount_applied'] = pd.to_numeric(df_sales_data['discount_applied'], errors='coerce')
#checking for negative values
df_sales_data[df_sales_data['quantity'] < 0]
df_sales_data[df_sales_data['unit_price'] < 0]
df_sales_data[df_sales_data['discount_applied'] < 0]
#replacing negative values with 0
df_sales_data.loc[df_sales_data['quantity'] < 0, 'quantity'] = 0
df_sales_data.loc[df_sales_data['unit_price'] < 0, 'unit_price'] = 0
df_sales_data.loc[df_sales_data['discount_applied'] < 0, 'discount_applied'] = 0

# %%
(df_sales_data[['quantity', 'unit_price', 'discount_applied']] < 0).sum()
#all possible <0 numbers are >0 now
# Out:
# quantity            0
# unit_price          0
# discount_applied    0
# dtype: int64

# %% [raw]
# -> Optionally filter or correct records with invalid values

# %%
#table1
for col in df_sales_data.columns:
    print(f"\n Checking the unique values if there is anything uncommon'{col}':")
    print(df_sales_data[col].unique())
# Out:
#  Checking the unique values if there is anything uncommon'order_id':
# ['O966977' 'O696648' 'O202644' ... 'O763639' 'O753958' 'O929624']
#
#  Checking the unique values if there is anything uncommon'customer_id':
# ['C00397' 'C00236' 'C00492' 'C00031' 'C00495' 'C00388' 'C00328' 'C00201'
#  'C00076' 'C00330' 'C00285' 'C00249' 'C00110' 'C00441' 'C00274' 'C00404'
#  'C00262' 'C00319' 'C00059' 'C00211' 'C00276' 'C00369' 'C00171' 'C00423'
#  'C00040' 'C00334' 'C00463' 'C00374' 'C00470' 'C00329' 'C00480' 'C00259'
#  'C00464' 'C00398' 'C00070' 'C00197' 'C00500' 'C00331' 'C00414' 'C00170'
#  'C00284' 'C00392' 'C00301' 'C00043' 'C00416' 'C00006' 'C00399' 'C00381'
#  'C00366' 'C00180' 'C00434' 'C00365' 'C00066' 'C00224' 'C00077' 'C00384'
#  'C00195' 'C00181' 'C00152' 'C00443' 'C00263' 'C00357' 'C00020' 'C00465'
#  'C00356' 'C00415' 'C00272' 'C00420' 'C00342' 'C00352' 'C00045' 'C00147'
#  'C00452' 'C00338' 'C00033' 'C00372' 'C00056' 'C00131' 'C00172' 'C00386'
# ...

# %%
#delivery_status
df_sales_data.loc[:, 'delivery_status'] = df_sales_data['delivery_status'].replace({
    'Delrd': 'Delayed',
    'Delyd': 'Delayed'})
#payment_method
df_sales_data.loc[:, 'payment_method'] = df_sales_data['payment_method'].replace({
    'Bank Transfr': 'Bank Transfer'})
#region
df_sales_data.loc[:, 'region'] = df_sales_data['region'].replace({
    'Nrth': 'North'})
#there are mistakes in the entries in delivery_status: 'Delrd', 'Delyd'; 
                                      #payment_method: 'Bank transf';
                                      #region:         'Nrth'

# %%
print(df_sales_data['delivery_status'].unique())
print(df_sales_data['payment_method'].unique())
print(df_sales_data['region'].unique())
# Out:
# ['Delivered' 'Delayed' 'Cancelled' 'Nan']
# ['Paypal' 'Credit Card' 'Bank Transfer' 'Nan']
# ['Central' 'North' 'West' 'East' 'South']

# %%
#table2
for col in df_product_info.columns:
    print(f"\n Checking the unique values if there is anything uncommon'{col}':")
    print(df_product_info[col].unique())
#there is nothing uncommon
# Out:
#  Checking the unique values if there is anything uncommon'product_id':
# ['P0001' 'P0002' 'P0003' 'P0004' 'P0005' 'P0006' 'P0007' 'P0008' 'P0009'
#  'P0010' 'P0011' 'P0012' 'P0013' 'P0014' 'P0015' 'P0016' 'P0017' 'P0018'
#  'P0019' 'P0020' 'P0021' 'P0022' 'P0023' 'P0024' 'P0025' 'P0026' 'P0027'
#  'P0028' 'P0029' 'P0030']
#
#  Checking the unique values if there is anything uncommon'product_name':
# ['Storage Product 39' 'Cleaning Product 82' 'Cleaning Product 85'
#  'Kitchen Product 82' 'Personal Care Product 1' 'Cleaning Product 16'
#  'Personal Care Product 64' 'Storage Product 47' 'Outdoors Product 13'
#  'Cleaning Product 70' 'Kitchen Product 53' 'Cleaning Product 29'
#  'Cleaning Product 94' 'Outdoors Product 91' 'Storage Product 10'
#  'Cleaning Product 53' 'Personal Care Product 11' 'Storage Product 37'
#  'Kitchen Product 42' 'Cleaning Product 40' 'Kitchen Product 70'
#  'Cleaning Product 86' 'Outdoors Product 32' 'Storage Product 87'
# ...

# %%
#table3
df_customer_info
for col in df_customer_info.columns:
    print(f"\n Checking the unique values if there is anything uncommon'{col}':")
    print(df_customer_info[col].unique())
# Out:
#  Checking the unique values if there is anything uncommon'customer_id':
# ['C00001' 'C00002' 'C00003' 'C00004' 'C00005' 'C00006' 'C00007' 'C00008'
#  'C00009' 'C00010' 'C00011' 'C00012' 'C00013' 'C00014' 'C00015' 'C00016'
#  'C00017' 'C00018' 'C00019' 'C00020' 'C00021' 'C00022' 'C00023' 'C00024'
#  'C00025' 'C00026' 'C00027' 'C00028' 'C00029' 'C00030' 'C00031' 'C00032'
#  'C00033' 'C00034' 'C00035' 'C00036' 'C00037' 'C00038' 'C00039' 'C00040'
#  'C00041' 'C00042' 'C00043' 'C00044' 'C00045' 'C00046' 'C00047' 'C00048'
#  'C00049' 'C00050' 'C00051' 'C00052' 'C00053' 'C00054' 'C00055' 'C00056'
#  'C00057' 'C00058' 'C00059' 'C00060' 'C00061' 'C00062' 'C00063' 'C00064'
#  'C00065' 'C00066' 'C00067' 'C00068' 'C00069' 'C00070' 'C00071' 'C00072'
#  'C00073' 'C00074' 'C00075' 'C00076' 'C00077' 'C00078' 'C00079' 'C00080'
#  'C00081' 'C00082' 'C00083' 'C00084' 'C00085' 'C00086' 'C00087' 'C00088'
#  'C00089' 'C00090' 'C00091' 'C00092' 'C00093' 'C00094' 'C00095' 'C00096'
# ...

# %%
#gender
df_customer_info.loc[:, 'gender'] = df_customer_info['gender'].replace({
    'Femle': 'Female'})
#loyalty_tier
df_customer_info.loc[:, 'loyalty_tier'] = df_customer_info['loyalty_tier'].replace({
    'Gld': 'Gold',
    'Brnze':'Bronze',
    'Sllver': 'Silver'})

# %%
print(df_customer_info['gender'].unique())
print(df_customer_info['loyalty_tier'].unique())
# Out:
# ['Male' 'Female' 'Other' 'unknown']
# ['Silver' 'Gold' 'Bronze' 'unknown']

# %% [raw]
# Merge the Data

# %% [raw]
# - Merge sales_data with product_info using product_id

# %%
merged_sales_data_product_info = pd.merge(df_sales_data, df_product_info, on='product_id', how='left')
merged_sales_data_product_info
# Out:
#      order_id customer_id product_id quantity  unit_price order_date  \
# 0     O966977      C00397      P0022      3.0       39.25 2006-07-25
# 1     O696648      C00236      P0023      5.0       18.92 2006-07-25
# 2     O202644      C00492      P0011      1.0       29.68 2006-07-25
# 3     O501803      C00031      P0003      1.0       32.76 2006-07-25
# 4     O322242      C00495      P0016      1.0       47.62 2006-07-25
# ...       ...         ...        ...      ...         ...        ...
# 2991  O868860      C00233      P0001      5.0       43.40 2006-07-25
# 2992  O949709      C00246      P0029      4.0       34.04 2006-07-25
# 2993  O763639      C00182      P0026      1.0       42.34 2006-07-25
# 2994  O753958      C00074      P0003      5.0       35.96 2006-07-25
# 2995  O929624      C00405      P0004      3.0       43.23 2006-07-25
#
#      delivery_status payment_method   region  discount_applied  \
# 0          Delivered         Paypal  Central              0.00
# ...

# %% [raw]
# - Then merge the result with customer_info using customer_id

# %%
merged_df = pd.merge(
    merged_sales_data_product_info, 
    df_customer_info, 
    on='customer_id', 
    how='left'
)
merged_df
# Out:
#      order_id customer_id product_id quantity  unit_price order_date  \
# 0     O966977      C00397      P0022      3.0       39.25 2006-07-25
# 1     O696648      C00236      P0023      5.0       18.92 2006-07-25
# 2     O202644      C00492      P0011      1.0       29.68 2006-07-25
# 3     O501803      C00031      P0003      1.0       32.76 2006-07-25
# 4     O322242      C00495      P0016      1.0       47.62 2006-07-25
# ...       ...         ...        ...      ...         ...        ...
# 2991  O868860      C00233      P0001      5.0       43.40 2006-07-25
# 2992  O949709      C00246      P0029      4.0       34.04 2006-07-25
# 2993  O763639      C00182      P0026      1.0       42.34 2006-07-25
# 2994  O753958      C00074      P0003      5.0       35.96 2006-07-25
# 2995  O929624      C00405      P0004      3.0       43.23 2006-07-25
#
#      delivery_status payment_method region_x  discount_applied  \
# 0          Delivered         Paypal  Central              0.00
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2996 entries, 0 to 2995
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          2996 non-null   object
#  1   customer_id       2996 non-null   object
#  2   product_id        2996 non-null   object
#  3   quantity          2991 non-null   object
#  4   unit_price        2996 non-null   float64
#  5   order_date        2996 non-null   datetime64[ns]
#  6   delivery_status   2996 non-null   object
#  7   payment_method    2996 non-null   object
#  8   region_x          2996 non-null   object
#  9   discount_applied  2479 non-null   float64
#  10  product_name      2991 non-null   object
#  11  category          2991 non-null   object
#  12  launch_date       2991 non-null   datetime64[ns]
#  13  base_price        2991 non-null   float64
#  14  supplier_code     2991 non-null   object
#  15  email             2970 non-null   object
# ...

# %%
merged_df.head()
# Out:
#   order_id customer_id product_id quantity  unit_price order_date  \
# 0  O966977      C00397      P0022      3.0       39.25 2006-07-25
# 1  O696648      C00236      P0023      5.0       18.92 2006-07-25
# 2  O202644      C00492      P0011      1.0       29.68 2006-07-25
# 3  O501803      C00031      P0003      1.0       32.76 2006-07-25
# 4  O322242      C00495      P0016      1.0       47.62 2006-07-25
#
#   delivery_status payment_method region_x  discount_applied  \
# 0       Delivered         Paypal  Central              0.00
# 1         Delayed    Credit Card    North              0.00
# 2       Delivered  Bank Transfer    North              0.15
# 3       Cancelled    Credit Card  Central              0.20
# 4         Delayed    Credit Card     West              0.20
#
#           product_name  category launch_date  base_price supplier_code  \
# 0  Cleaning Product 86  Cleaning  2004-10-24       19.77          S924
# ...

# %% [raw]
# Feature Engineering

# %% [raw]
# Create the following new columns:
# • revenue = quantity × unit_price × (1 - discount_applied)
# • order_week = ISO week from order_date
# • price_band = Categorise unit price as Low (<£15), Medium (£15–30), High (>£30)
# • days_to_order = Days between launch_date and order_date
# • email_domain = Extract domain from email (e.g., gmail.com)
# • is_late = True if delivery_status is "Delayed"

# %%
merged_df['revenue'] = merged_df['quantity'] * merged_df['unit_price'] * (1 - merged_df['discount_applied'])
merged_df['order_week'] = merged_df['order_date'].dt.isocalendar().week
merged_df['price_band'] = pd.cut(
    merged_df['unit_price'],
    bins=[-float('inf'), 15, 30, float('inf')],
    labels=['Low', 'Medium', 'High'])
merged_df['days_to_order'] = (merged_df['order_date'] - merged_df['launch_date']).dt.days
merged_df['email_domain'] = merged_df['email'].map(lambda x: x.split('@')[1] if pd.notnull(x) and '@' in x else None)
merged_df['is_late'] = merged_df['delivery_status'] == 'Delayed'
merged_df
# Out:
#      order_id customer_id product_id quantity  unit_price order_date  \
# 0     O966977      C00397      P0022      3.0       39.25 2006-07-25
# 1     O696648      C00236      P0023      5.0       18.92 2006-07-25
# 2     O202644      C00492      P0011      1.0       29.68 2006-07-25
# 3     O501803      C00031      P0003      1.0       32.76 2006-07-25
# 4     O322242      C00495      P0016      1.0       47.62 2006-07-25
# ...       ...         ...        ...      ...         ...        ...
# 2991  O868860      C00233      P0001      5.0       43.40 2006-07-25
# 2992  O949709      C00246      P0029      4.0       34.04 2006-07-25
# 2993  O763639      C00182      P0026      1.0       42.34 2006-07-25
# 2994  O753958      C00074      P0003      5.0       35.96 2006-07-25
# 2995  O929624      C00405      P0004      3.0       43.23 2006-07-25
#
#      delivery_status payment_method region_x  discount_applied  ...  \
# 0          Delivered         Paypal  Central              0.00  ...
# ...

# %%
#days_to_order are negative because some of the original entries in launch_date is later 
#than the order_date. Therefore, I remove the rows that contain negative days_to_order.
merged_df = merged_df[merged_df['days_to_order'] >= 0]
merged_df
# Out:
#      order_id customer_id product_id quantity  unit_price order_date  \
# 0     O966977      C00397      P0022      3.0       39.25 2006-07-25
# 8     O170570      C00076      P0030      3.0       28.32 2006-07-25
# 10    O490023      C00285      P0022      2.0        9.98 2006-07-25
# 11    O865247      C00249      P0022      5.0       30.92 2006-07-25
# 21    O121091      C00276      P0022      4.0       12.88 2006-07-25
# ...       ...         ...        ...      ...         ...        ...
# 2957  O677936      C00059      P0030      1.0       45.30 2006-07-25
# 2961  O284155      C00292      P0030      4.0       17.73 2006-07-25
# 2962  O814926      C00469      P0014      5.0       27.89 2006-07-25
# 2983  O422603      C00415      P0014      1.0       10.74 2006-07-25
# 2986  O584546      C00250      P0030      3.0       34.37 2006-07-25
#
#      delivery_status payment_method region_x  discount_applied  ...  \
# 0          Delivered         Paypal  Central              0.00  ...
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 313 entries, 0 to 2986
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          313 non-null    object
#  1   customer_id       313 non-null    object
#  2   product_id        313 non-null    object
#  3   quantity          313 non-null    object
#  4   unit_price        313 non-null    float64
#  5   order_date        313 non-null    datetime64[ns]
#  6   delivery_status   313 non-null    object
#  7   payment_method    313 non-null    object
#  8   region_x          313 non-null    object
#  9   discount_applied  259 non-null    float64
#  10  product_name      313 non-null    object
#  11  category          313 non-null    object
#  12  launch_date       313 non-null    datetime64[ns]
#  13  base_price        313 non-null    float64
#  14  supplier_code     313 non-null    object
#  15  email             312 non-null    object
# ...

# %% [raw]
# Create Summary Tables

# %% [raw]
# - Using groupby(), agg(), pivot_table(), or query():

# %% [raw]
# -> Weekly revenue trends by region

# %%
merged_df['order_week'].unique()
# Out:
# <IntegerArray>
# [30]
# Length: 1, dtype: UInt32

# %%
#Because it was told in the description to merge sales_data with product_info, then merge with customer_info using a left join to preserve all sales transactions.
#Therefore, the analysis is about sales. A left join preserves the original data from sales_data. So, the region tied to the sale itself (region_x, from df_sales_data) is the one that aligns directly with each order.
#A region from sales_data shows where the order happened.
#A region from customer_info shows where the customer is registered, not where the transaction occurred.
weekly_revenue = merged_df.groupby(['order_week', 'region_x'])['revenue'].sum().reset_index()
weekly_revenue
# Out:
#    order_week region_x    revenue
# 0          30  Central    4073.51
# 1          30     East   4223.303
# 2          30    North   2891.934
# 3          30    South  4197.6225
# 4          30     West  4262.5505

# %% [raw]
# -> Product category performance (revenue, quantity, discount)

# %%
product_category_performance = merged_df.groupby('category').agg({
    'revenue': 'sum',
    'quantity': 'sum',
    'discount_applied': 'mean'}).reset_index()
product_category_performance
# Out:
#    category     revenue quantity  discount_applied
# 0  Cleaning  12742.4645    621.0          0.100602
# 1  Outdoors   6906.4555    355.0          0.108065

# %% [raw]
# -> Customer behaviour by loyalty_tier and signup_month

# %%
merged_df['signup_month'] = merged_df['signup_date'].dt.to_period('M')

customer_behavior = pd.pivot_table(
    merged_df,
    values='revenue',
    index='loyalty_tier',
    columns='signup_month',
    aggfunc='sum',
    fill_value=0
)
customer_behavior
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_51760\693395220.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df['signup_month'] = merged_df['signup_date'].dt.to_period('M')
# C:\Users\User\AppData\Local\Temp\ipykernel_51760\693395220.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   customer_behavior = pd.pivot_table(
# signup_month  2001-01  2001-02  2001-04  2001-07  2001-10  2001-11  2002-01  \
# loyalty_tier
# Bronze          0.000        0    0.000    0.000   47.796    0.000      0.0
# ...

# %%
customer_behavior = (
    merged_df
    .groupby(['loyalty_tier', 'signup_month'])['revenue']
    .sum()
    .unstack(fill_value=0)
)
customer_behavior
# Out:
# signup_month 2001-01 2001-02 2001-04 2001-07 2001-10 2001-11 2002-01 2002-03  \
# loyalty_tier
# Bronze             0       0       0       0  47.796       0       0       0
# Gold               0       0  37.288  42.194       0       0    11.2   34.28
# Silver        51.204       0       0       0       0  46.821       0       0
# unknown            0       0       0       0       0       0       0       0
#
# signup_month  2002-05  2002-06  ... 2030-01  2030-05 2030-08   2030-09  \
# loyalty_tier                    ...
# Bronze        44.4315        0  ...       0        0       0         0
# Gold                0        0  ...       0  59.7355  100.56  679.3875
# Silver              0  157.985  ...       0        0  133.86         0
# unknown             0        0  ...       0        0       0         0
#
# signup_month 2030-11 2030-12  2031-01 2031-05 2031-10 2031-12
# loyalty_tier
# Bronze             0       0        0       0       0       0
# ...

# %% [raw]
# -> Delivery performance by region and price_band

# %%
delivery_performance = merged_df.groupby(['region_x', 'price_band']).agg({
    'is_late': 'mean'
}).reset_index()
delivery_performance
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_51760\2043538815.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   delivery_performance = merged_df.groupby(['region_x', 'price_band']).agg({
#    region_x price_band   is_late
# 0   Central        Low  0.461538
# 1   Central     Medium  0.576923
# 2   Central       High  0.428571
# 3      East        Low  0.400000
# 4      East     Medium  0.347826
# 5      East       High  0.480000
# 6     North        Low  0.428571
# 7     North     Medium  0.450000
# 8     North       High  0.360000
# 9     South        Low  0.176471
# 10    South     Medium  0.318182
# 11    South       High  0.343750
# 12     West        Low  0.500000
# 13     West     Medium  0.400000
# 14     West       High  0.400000

# %% [raw]
# -> Preferred payment methods by loyalty_tier

# %%
#query() excludes missing values and the values 'unknown' payment method
filtered_df = merged_df.query("loyalty_tier == loyalty_tier and loyalty_tier != 'unknown'")

preferred_payment_methods = filtered_df.groupby(['loyalty_tier', 'payment_method']).size().reset_index(name='count')
preferred_payment_methods
# Out:
#   loyalty_tier payment_method  count
# 0       Bronze  Bank Transfer     18
# 1       Bronze    Credit Card     36
# 2       Bronze         Paypal     17
# 3         Gold  Bank Transfer     25
# 4         Gold    Credit Card    101
# 5         Gold         Paypal     44
# 6       Silver  Bank Transfer     20
# 7       Silver    Credit Card     33
# 8       Silver         Paypal     17

# %% [raw]
# Visual Exploration

# %% [raw]
# - Create at least 6 clear and labelled visualisations using Matplotlib and Seaborn. Suggested
# charts:

# %% [raw]
# ->  Line plot - weekly revenue trends by region

# %%
# !pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(data=weekly_revenue, x='order_week', y='revenue', hue='region_x', marker='o')
plt.title('Line Plot - Weekly Revenue Trends by Region')
plt.xlabel('Order Week')
plt.ylabel('Revenue')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [raw]
# ->  Bar chart - top 5 categories by revenue

# %%
print(merged_df['revenue'].dtype)
print(merged_df['revenue'].isna().sum())
#there are 54 NaN values and because of them not all 5 categories are shown.
# Out:
# object
# 54

# %%
category_revenue = (
    merged_df.groupby('category')['revenue'].sum().sort_values(ascending=False).head(5).reset_index()
)
plt.figure(figsize=(4, 2))
sns.barplot(data=category_revenue, x='revenue', y='category', palette='viridis')
plt.title('Bar Chart - Top 5 Categories by Revenue')
plt.xlabel('Total Revenue')
plt.ylabel('Product Category')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_51760\2080711058.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=category_revenue, x='revenue', y='category', palette='viridis')

# %% [raw]
# -> Boxplot - quantity vs discount across categories

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=filtered_df, x='category', y='quantity', hue='discount_applied')
plt.title('Quantity vs Discount across Categories')
plt.xlabel('Product Category')
plt.ylabel('Quantity Ordered')
plt.legend(title='Discount Applied', bbox_to_anchor=(1, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [raw]
# -> Heatmap - correlation between revenue, discount, and quantity

# %%
merged_df = merged_df.copy()

merged_df.loc[:, 'quantity'] = pd.to_numeric(merged_df['quantity'], errors='coerce')
merged_df.loc[:, 'revenue'] = pd.to_numeric(merged_df['revenue'], errors='coerce')
merged_df.loc[:, 'discount_applied'] = pd.to_numeric(merged_df['discount_applied'], errors='coerce')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

merged_df['quantity'] = pd.to_numeric(merged_df['quantity'], errors='coerce')
merged_df['revenue'] = pd.to_numeric(merged_df['revenue'], errors='coerce')
merged_df['discount_applied'] = pd.to_numeric(merged_df['discount_applied'], errors='coerce')

corr = merged_df[['revenue', 'quantity', 'discount_applied']].corr()

plt.figure(figsize=(6, 4))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation: Revenue, Quantity, Discount')
plt.tight_layout()
plt.show()

# %% [raw]
# -> Stacked bar or pie - delivery status by price band

# %%
delivery_status_by_band = merged_df.pivot_table(
    index='price_band',
    columns='delivery_status',
    values='order_id',
    aggfunc='count',
    fill_value=0,
    observed=False
)
delivery_status_by_band.plot(kind='bar', stacked=True)
plt.title('Delivery Status by Price Band')
plt.xlabel('Price Band')
plt.ylabel('Number of Orders')
plt.xticks(rotation=0)
plt.legend(title='Delivery Status')
plt.tight_layout()
plt.show()
